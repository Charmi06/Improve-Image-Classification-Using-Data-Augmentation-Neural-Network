# %%
from __future__ import print_function
import keras
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten,GaussianNoise
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from IPython.display import Image
import cv2
import seaborn as sns; sns.set()
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
x_train  = x_train/255
x_test  = x_test/255

# %%
one_hot_encoder = OneHotEncoder(sparse=False)

# %%
one_hot_encoder.fit(y_train)
# Out:
# OneHotEncoder(sparse=False)

# %%
y_train = one_hot_encoder.transform(y_train)
y_test = one_hot_encoder.transform(y_test)

# %%
# we will do some mild image pre-processing for augmentation
datagen = ImageDataGenerator(
    rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,
    zca_epsilon=1e-06,fill_mode='nearest',)  # randomly flip images

# %%
num_classes = 10

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:],name='conv1'))
model.add(BatchNormalization(axis=3, name='bn_conv1'))
model.add(Activation('elu'))
model.add(Conv2D(32, (3, 3), padding='same',name='conv2'))
model.add(BatchNormalization(axis=3, name='bn_conv2'))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding='same',name='conv3'))
model.add(BatchNormalization(axis=3, name='bn_conv3'))
model.add(Activation('elu'))
model.add(Conv2D(64, (3, 3), padding='same',name='conv4'))
model.add(BatchNormalization(axis=3, name='bn_conv4'))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(128, (3, 3), padding='same',name='conv5'))
model.add(BatchNormalization(axis=3, name='bn_conv5'))
model.add(Activation('elu'))
model.add(Conv2D(128, (3, 3), padding='same',name='conv6'))
model.add(BatchNormalization(axis=3, name='bn_conv6'))
model.add(Activation('elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,name='fc1'))
model.add(GaussianNoise(0.1))
model.add(Activation('elu'))
model.add(Dense(num_classes,name='output'))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy',optimizer='Adamax',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        896
#
#  bn_conv1 (BatchNormalizatio  (None, 32, 32, 32)       128
#  n)
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  bn_conv2 (BatchNormalizatio  (None, 32, 32, 32)       128
#  n)
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  bn_conv3 (BatchNormalizatio  (None, 16, 16, 64)       256
#  n)
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  bn_conv4 (BatchNormalizatio  (None, 16, 16, 64)       256
#  n)
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  bn_conv5 (BatchNormalizatio  (None, 8, 8, 128)        512
#  n)
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  bn_conv6 (BatchNormalizatio  (None, 8, 8, 128)        512
#  n)
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout (Dropout)           (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 512)               1049088
#
#  gaussian_noise (GaussianNoi  (None, 512)              0
#  se)
#
#  activation_6 (Activation)   (None, 512)               0
#
#  output (Dense)              (None, 10)                5130
#
#  activation_7 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 1,343,018
# Trainable params: 1,342,122
# Non-trainable params: 896
# _________________________________________________________________

# %%
batch_size = 32
epochs = 100
model_history = model.fit(datagen.flow(x_train, y_train,
                                 batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 1562/1562 [==============================] - 52s 27ms/step - loss: 1.4647 - accuracy: 0.4871 - val_loss: 1.1827 - val_accuracy: 0.5871
# Epoch 2/100
# 1562/1562 [==============================] - 43s 28ms/step - loss: 1.0448 - accuracy: 0.6311 - val_loss: 1.0229 - val_accuracy: 0.6561
# Epoch 3/100
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.8906 - accuracy: 0.6856 - val_loss: 0.7869 - val_accuracy: 0.7250
# Epoch 4/100
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.7984 - accuracy: 0.7205 - val_loss: 0.7719 - val_accuracy: 0.7395
# Epoch 5/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.7375 - accuracy: 0.7426 - val_loss: 0.7477 - val_accuracy: 0.7488
# Epoch 6/100
# 1562/1562 [==============================] - 41s 27ms/step - loss: 0.6810 - accuracy: 0.7613 - val_loss: 0.6214 - val_accuracy: 0.7916
# Epoch 7/100
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.6442 - accuracy: 0.7737 - val_loss: 0.6325 - val_accuracy: 0.7836
# Epoch 8/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.6121 - accuracy: 0.7855 - val_loss: 0.6286 - val_accuracy: 0.7836
# Epoch 9/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.5763 - accuracy: 0.7986 - val_loss: 0.7311 - val_accuracy: 0.7617
# Epoch 10/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.5546 - accuracy: 0.8047 - val_loss: 0.7065 - val_accuracy: 0.7691
# Epoch 11/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.5280 - accuracy: 0.8151 - val_loss: 0.5783 - val_accuracy: 0.8078
# Epoch 12/100
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.5071 - accuracy: 0.8226 - val_loss: 0.4823 - val_accuracy: 0.8347
# Epoch 13/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.4903 - accuracy: 0.8286 - val_loss: 0.5531 - val_accuracy: 0.8158
# Epoch 14/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.4703 - accuracy: 0.8353 - val_loss: 0.5765 - val_accuracy: 0.8101
# Epoch 15/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.4551 - accuracy: 0.8421 - val_loss: 0.4999 - val_accuracy: 0.8288
# Epoch 16/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.4409 - accuracy: 0.8483 - val_loss: 0.5053 - val_accuracy: 0.8280
# Epoch 17/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.4267 - accuracy: 0.8509 - val_loss: 0.4844 - val_accuracy: 0.8374
# Epoch 18/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.4139 - accuracy: 0.8563 - val_loss: 0.4913 - val_accuracy: 0.8334
# Epoch 19/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.4000 - accuracy: 0.8600 - val_loss: 0.4501 - val_accuracy: 0.8520
# Epoch 20/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.3911 - accuracy: 0.8630 - val_loss: 0.4766 - val_accuracy: 0.8428
# Epoch 21/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.3791 - accuracy: 0.8670 - val_loss: 0.4976 - val_accuracy: 0.8377
# Epoch 22/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3723 - accuracy: 0.8698 - val_loss: 0.5448 - val_accuracy: 0.8256
# Epoch 23/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.3627 - accuracy: 0.8736 - val_loss: 0.4552 - val_accuracy: 0.8456
# Epoch 24/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3529 - accuracy: 0.8764 - val_loss: 0.4608 - val_accuracy: 0.8461
# Epoch 25/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3413 - accuracy: 0.8811 - val_loss: 0.4615 - val_accuracy: 0.8496
# Epoch 26/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3378 - accuracy: 0.8815 - val_loss: 0.4190 - val_accuracy: 0.8617
# Epoch 27/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3289 - accuracy: 0.8854 - val_loss: 0.5031 - val_accuracy: 0.8384
# Epoch 28/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3162 - accuracy: 0.8871 - val_loss: 0.4070 - val_accuracy: 0.8616
# Epoch 29/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.3108 - accuracy: 0.8899 - val_loss: 0.4968 - val_accuracy: 0.8420
# Epoch 30/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.3045 - accuracy: 0.8920 - val_loss: 0.4474 - val_accuracy: 0.8527
# Epoch 31/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.2996 - accuracy: 0.8942 - val_loss: 0.4354 - val_accuracy: 0.8631
# Epoch 32/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2934 - accuracy: 0.8969 - val_loss: 0.4554 - val_accuracy: 0.8554
# Epoch 33/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2867 - accuracy: 0.8986 - val_loss: 0.4421 - val_accuracy: 0.8543
# Epoch 34/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2781 - accuracy: 0.9023 - val_loss: 0.4105 - val_accuracy: 0.8659
# Epoch 35/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2754 - accuracy: 0.9042 - val_loss: 0.4133 - val_accuracy: 0.8660
# Epoch 36/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2665 - accuracy: 0.9054 - val_loss: 0.4308 - val_accuracy: 0.8624
# Epoch 37/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.2614 - accuracy: 0.9077 - val_loss: 0.4173 - val_accuracy: 0.8657
# Epoch 38/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2597 - accuracy: 0.9094 - val_loss: 0.3918 - val_accuracy: 0.8708
# Epoch 39/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2551 - accuracy: 0.9091 - val_loss: 0.4472 - val_accuracy: 0.8582
# Epoch 40/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2456 - accuracy: 0.9140 - val_loss: 0.4469 - val_accuracy: 0.8675
# Epoch 41/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.2427 - accuracy: 0.9147 - val_loss: 0.4410 - val_accuracy: 0.8625
# Epoch 42/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2392 - accuracy: 0.9150 - val_loss: 0.4127 - val_accuracy: 0.8690
# Epoch 43/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2373 - accuracy: 0.9161 - val_loss: 0.3991 - val_accuracy: 0.8704
# Epoch 44/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2293 - accuracy: 0.9184 - val_loss: 0.4015 - val_accuracy: 0.8724
# Epoch 45/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2265 - accuracy: 0.9191 - val_loss: 0.4130 - val_accuracy: 0.8706
# Epoch 46/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2221 - accuracy: 0.9222 - val_loss: 0.4290 - val_accuracy: 0.8664
# Epoch 47/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2238 - accuracy: 0.9209 - val_loss: 0.4367 - val_accuracy: 0.8639
# Epoch 48/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2134 - accuracy: 0.9248 - val_loss: 0.4138 - val_accuracy: 0.8697
# Epoch 49/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2140 - accuracy: 0.9245 - val_loss: 0.4403 - val_accuracy: 0.8647
# Epoch 50/100
# 1562/1562 [==============================] - 39s 25ms/step - loss: 0.2110 - accuracy: 0.9254 - val_loss: 0.4102 - val_accuracy: 0.8716
# Epoch 51/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.2055 - accuracy: 0.9271 - val_loss: 0.4397 - val_accuracy: 0.8653
# Epoch 52/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.2048 - accuracy: 0.9266 - val_loss: 0.4324 - val_accuracy: 0.8676
# Epoch 53/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.2001 - accuracy: 0.9284 - val_loss: 0.4566 - val_accuracy: 0.8685
# Epoch 54/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1980 - accuracy: 0.9297 - val_loss: 0.4140 - val_accuracy: 0.8767
# Epoch 55/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.1890 - accuracy: 0.9322 - val_loss: 0.4108 - val_accuracy: 0.8760
# Epoch 56/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1936 - accuracy: 0.9318 - val_loss: 0.4113 - val_accuracy: 0.8774
# Epoch 57/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.1894 - accuracy: 0.9323 - val_loss: 0.4309 - val_accuracy: 0.8729
# Epoch 58/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1839 - accuracy: 0.9332 - val_loss: 0.4096 - val_accuracy: 0.8802
# Epoch 59/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1829 - accuracy: 0.9344 - val_loss: 0.4382 - val_accuracy: 0.8739
# Epoch 60/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1824 - accuracy: 0.9358 - val_loss: 0.4208 - val_accuracy: 0.8736
# Epoch 61/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1799 - accuracy: 0.9356 - val_loss: 0.4540 - val_accuracy: 0.8678
# Epoch 62/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1772 - accuracy: 0.9364 - val_loss: 0.3945 - val_accuracy: 0.8817
# Epoch 63/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1721 - accuracy: 0.9390 - val_loss: 0.4270 - val_accuracy: 0.8748
# Epoch 64/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1704 - accuracy: 0.9401 - val_loss: 0.4381 - val_accuracy: 0.8710
# Epoch 65/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1722 - accuracy: 0.9388 - val_loss: 0.4325 - val_accuracy: 0.8724
# Epoch 66/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1672 - accuracy: 0.9413 - val_loss: 0.4095 - val_accuracy: 0.8745
# Epoch 67/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1632 - accuracy: 0.9424 - val_loss: 0.4076 - val_accuracy: 0.8828
# Epoch 68/100
# 1562/1562 [==============================] - 39s 25ms/step - loss: 0.1623 - accuracy: 0.9422 - val_loss: 0.4129 - val_accuracy: 0.8811
# Epoch 69/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1589 - accuracy: 0.9436 - val_loss: 0.4129 - val_accuracy: 0.8771
# Epoch 70/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1579 - accuracy: 0.9444 - val_loss: 0.4162 - val_accuracy: 0.8766
# Epoch 71/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1581 - accuracy: 0.9449 - val_loss: 0.4355 - val_accuracy: 0.8748
# Epoch 72/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1551 - accuracy: 0.9451 - val_loss: 0.4385 - val_accuracy: 0.8774
# Epoch 73/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1553 - accuracy: 0.9447 - val_loss: 0.4277 - val_accuracy: 0.8767
# Epoch 74/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1496 - accuracy: 0.9477 - val_loss: 0.4474 - val_accuracy: 0.8759
# Epoch 75/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1467 - accuracy: 0.9492 - val_loss: 0.4069 - val_accuracy: 0.8835
# Epoch 76/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1510 - accuracy: 0.9466 - val_loss: 0.4163 - val_accuracy: 0.8765
# Epoch 77/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1405 - accuracy: 0.9500 - val_loss: 0.4015 - val_accuracy: 0.8827
# Epoch 78/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1462 - accuracy: 0.9479 - val_loss: 0.4391 - val_accuracy: 0.8769
# Epoch 79/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1459 - accuracy: 0.9479 - val_loss: 0.4271 - val_accuracy: 0.8791
# Epoch 80/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.1432 - accuracy: 0.9485 - val_loss: 0.4486 - val_accuracy: 0.8793
# Epoch 81/100
# 1562/1562 [==============================] - 40s 25ms/step - loss: 0.1407 - accuracy: 0.9511 - val_loss: 0.4672 - val_accuracy: 0.8724
# Epoch 82/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1380 - accuracy: 0.9501 - val_loss: 0.4482 - val_accuracy: 0.8780
# Epoch 83/100
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.1422 - accuracy: 0.9491 - val_loss: 0.4457 - val_accuracy: 0.8769
# Epoch 84/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1315 - accuracy: 0.9533 - val_loss: 0.4215 - val_accuracy: 0.8772
# Epoch 85/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1342 - accuracy: 0.9521 - val_loss: 0.4507 - val_accuracy: 0.8759
# Epoch 86/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1342 - accuracy: 0.9527 - val_loss: 0.4149 - val_accuracy: 0.8828
# Epoch 87/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1325 - accuracy: 0.9536 - val_loss: 0.4305 - val_accuracy: 0.8791
# Epoch 88/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1306 - accuracy: 0.9544 - val_loss: 0.4272 - val_accuracy: 0.8794
# Epoch 89/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1332 - accuracy: 0.9521 - val_loss: 0.4089 - val_accuracy: 0.8878
# Epoch 90/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1312 - accuracy: 0.9535 - val_loss: 0.4230 - val_accuracy: 0.8834
# Epoch 91/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1276 - accuracy: 0.9547 - val_loss: 0.4825 - val_accuracy: 0.8735
# Epoch 92/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1248 - accuracy: 0.9555 - val_loss: 0.4118 - val_accuracy: 0.8841
# Epoch 93/100
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.1241 - accuracy: 0.9559 - val_loss: 0.4363 - val_accuracy: 0.8809
# Epoch 94/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1224 - accuracy: 0.9569 - val_loss: 0.4392 - val_accuracy: 0.8844
# Epoch 95/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1196 - accuracy: 0.9576 - val_loss: 0.4121 - val_accuracy: 0.8865
# Epoch 96/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1214 - accuracy: 0.9574 - val_loss: 0.4329 - val_accuracy: 0.8866
# Epoch 97/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1211 - accuracy: 0.9567 - val_loss: 0.4206 - val_accuracy: 0.8839
# Epoch 98/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1185 - accuracy: 0.9580 - val_loss: 0.4703 - val_accuracy: 0.8761
# Epoch 99/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1146 - accuracy: 0.9596 - val_loss: 0.4515 - val_accuracy: 0.8832
# Epoch 100/100
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.1188 - accuracy: 0.9580 - val_loss: 0.4131 - val_accuracy: 0.8859

# %%
model.save('M1-1.h5')

# %%
from keras import models
model = models.load_model('M1-1.h5')

# %%
predictions = model.predict(x_test)
predictions = one_hot_encoder.inverse_transform(predictions)
y_test = one_hot_encoder.inverse_transform(y_test)

# %%
cm = confusion_matrix(y_test, predictions)

# %%
y_test = y_test.astype(int)
predictions = predictions.astype(int)

# %%
fig = plt.figure()
fig.patch.set_facecolor('white')

plt.plot(model_history.history['accuracy'],
         label='train accuracy ',
         c='blue', ls='-')
plt.plot(model_history.history['val_accuracy'],
         label='test accuracy ',
         c='orange',ls='--')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig = plt.figure()
fig.patch.set_facecolor('white')

plt.plot(model_history.history['loss'],
         label='train loss',
         c='blue', ls='-')
plt.plot(model_history.history['val_loss'],
         label='test loss',
         c='orange',ls='--')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
fig, axes = plt.subplots(ncols=7, nrows=3, sharex=False,
    sharey=True, figsize=(17, 8))
index = 0
for i in range(3):
    for j in range(7):
        axes[i,j].set_title('actual:' + classes[y_test[index][0]] + '\n' 
                            + 'predicted:' + classes[predictions[index][0]])
        axes[i,j].imshow(x_test[index], cmap='gray')
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        index += 1
plt.show()

# %%
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=classes, yticklabels=classes,fmt='d', annot=True, cmap=plt.cm.Blues)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
